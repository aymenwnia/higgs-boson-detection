# %% [markdown]
# ***
# # Starting Kit - Black Swan HiggsML Course
# ***

# %%
COLAB = "google.colab" in str(get_ipython())

# %%
if COLAB:
    ! git clone --depth 1 https://github.com/blackSwanCS/Higgs_collaboration_B.git
    ! git status
    # %cd /Higgs_collaboration_B

# %%
# HiggsML utility package should not be modified
# %pip install HiggsML
# Out:
# Requirement already satisfied: HiggsML in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (0.1.5)
# Collecting argparse>=1.4.0 (from HiggsML)
#   Using cached argparse-1.4.0-py2.py3-none-any.whl.metadata (2.8 kB)
# Requirement already satisfied: matplotlib>=3.8.0 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from HiggsML) (3.9.2)
# Requirement already satisfied: mpld3>=0.5.8 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from HiggsML) (0.5.10)
# Requirement already satisfied: numpy>=1.26.4 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from HiggsML) (2.2.6)
# Requirement already satisfied: pandas>=2.2.2 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from HiggsML) (2.2.3)
# Requirement already satisfied: pyarrow>=15.0.0 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from HiggsML) (20.0.0)
# Requirement already satisfied: requests>=2.31.0 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from HiggsML) (2.32.3)
# Requirement already satisfied: scikit-learn>=1.4.2 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from HiggsML) (1.6.1)
# Requirement already satisfied: seaborn>=0.13.1 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from HiggsML) (0.13.2)
# Requirement already satisfied: tabulate>=0.9.0 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from HiggsML) (0.9.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.8.0->HiggsML) (1.3.1)
# Requirement already satisfied: cycler>=0.10 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.8.0->HiggsML) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.8.0->HiggsML) (4.55.0)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.8.0->HiggsML) (1.4.7)
# Requirement already satisfied: packaging>=20.0 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.8.0->HiggsML) (24.2)
# Requirement already satisfied: pillow>=8 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.8.0->HiggsML) (11.0.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.8.0->HiggsML) (3.2.0)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from matplotlib>=3.8.0->HiggsML) (2.9.0.post0)
# Requirement already satisfied: jinja2 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from mpld3>=0.5.8->HiggsML) (3.1.4)
# Requirement already satisfied: pytz>=2020.1 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.2.2->HiggsML) (2024.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from pandas>=2.2.2->HiggsML) (2024.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31.0->HiggsML) (3.4.2)
# Requirement already satisfied: idna<4,>=2.5 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31.0->HiggsML) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31.0->HiggsML) (2.4.0)
# Requirement already satisfied: certifi>=2017.4.17 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from requests>=2.31.0->HiggsML) (2025.4.26)
# Requirement already satisfied: scipy>=1.6.0 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.4.2->HiggsML) (1.15.3)
# Requirement already satisfied: joblib>=1.2.0 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.4.2->HiggsML) (1.5.1)
# Requirement already satisfied: threadpoolctl>=3.1.0 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from scikit-learn>=1.4.2->HiggsML) (3.6.0)
# Requirement already satisfied: six>=1.5 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from python-dateutil>=2.7->matplotlib>=3.8.0->HiggsML) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in c:\users\administrateur\appdata\local\programs\python\python312\lib\site-packages (from jinja2->mpld3>=0.5.8->HiggsML) (3.0.2)
# Using cached argparse-1.4.0-py2.py3-none-any.whl (23 kB)
# Installing collected packages: argparse
# Successfully installed argparse-1.4.0
# Note: you may need to restart the kernel to use updated packages.
# [notice] A new release of pip is available: 24.3.1 -> 25.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# ### Imports

# %%
from sys import path
import numpy as np
import pandas as pd
import json
import matplotlib.pyplot as plt
from itertools import product
from numpy.random import RandomState
import warnings
import os
import sys

warnings.filterwarnings("ignore")

# %% [markdown]
# ### Directories

# %%
root_dir = os.getcwd()
print("Root directory is", root_dir)
submission_dir = os.path.join(root_dir, "sample_code_submission")

# The directory where results and other outputs from the participant's code will be written
output_dir = os.path.join(root_dir, "sample_result_submission")

if not os.path.exists(output_dir):
    os.makedirs(output_dir)
# Out:
# Root directory is c:\Users\Administrateur\Downloads\git-higgs-B\Higgs_collaboration_B

# %% [markdown]
# ## Import Submission Model
# We import a class named `Model` from the submission file (`model.py`). This `Model` class has the following methods:
# - `init`: receives train set and systematics class as input
# - `fit`: can be used for training
# - `predict`: receives one test set and outputs a dictionary with the following keys
#     - `mu_hat` : predicted mu $\hat{\mu}$
#     - `delta_mu_hat`: $\Delta{\hat{\mu}}$ bound for $\mu$
#     - `p16`: 16th percentile
#     - `p84`: 84th percentile
#
# In this example code, the `Model` class implements a basic model with 2 different model trained to predict the class label.
#
# * 1 XGBoost BDT ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/boosted_decision_tree.py) )
# * 2 Tebsorflow NN  ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/neural_network.py) )
#
# The feature engineering is in where you can include derived quantities and decide which feature should be needed. ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/feature_engineering.py) )
#
# the statistical analysis part is where yoiu write the mu finding calculation using the output of the classifier. ( [see](/home/chakkappai/Work/ST4_CS/Collaboration_A/sample_code_submission/statistical_analysis.py) )
#
# If running in Collab, click the folder icon in the left sidebar to open the file browser.

# %%
path.append(submission_dir)
from sample_code_submission.model import Model

# %% [markdown]
# ## Data
# ### Available data sets
# 1. blackSwan_data
# 2. sample_data
# 3. neurips2024_data

# %%
from HiggsML.datasets import download_dataset

data = download_dataset(
    "blackSwan_data"
)  # change to "blackSwan_data" for the actual data
# Out:
# 2025-06-05 21:28:29,832 - HiggsML.datasets     - INFO     - Handling as dataset name: blackSwan_data
# 2025-06-05 21:28:29,834 - HiggsML.datasets     - INFO     - Current working directory: c:\Users\Administrateur\Downloads\git-higgs-B\Higgs_collaboration_B
# 2025-06-05 21:28:29,919 - HiggsML.datasets     - INFO     - Total rows: 2000000
# 2025-06-05 21:28:29,921 - HiggsML.datasets     - INFO     - Test size: 600000

# %% [markdown]
# ### ⚠️ Note:
# The data used here is a small subset of the full data is for demonstration only to get a view of what the data looks like.

# %%
# load train set
data.load_train_set()
data_set = data.get_train_set()
print(data_set)
# Out:
# 2025-06-05 21:28:30,588 - HiggsML.datasets     - INFO     - Selected train size: 1400000
# 2025-06-05 21:28:35,230 - HiggsML.datasets     - INFO     - Data loaded successfully
#          PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  PRI_had_pt  PRI_had_eta  \
# 0         37.472000        0.676       -1.520   46.752998        0.623
# 1         26.006001       -0.087       -1.412   60.009998       -0.290
# 2         20.622999       -0.922       -0.436   41.917999       -1.356
# 3         48.394001        0.202        0.816   27.916000       -0.552
# 4         39.840000       -0.005        1.487   30.997000        1.747
# ...             ...          ...          ...         ...          ...
# 1399995   28.957001        0.489       -1.468   31.007000       -1.381
# 1399996   23.759001       -0.805        2.832   35.183998       -0.923
# 1399997   29.795000        0.429        0.363   33.636002        0.731
# 1399998   48.626999        1.340        0.538   73.736000        0.437
# 1399999   33.832001        1.496        0.137   35.353001        1.300
#
#          PRI_had_phi  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# 0              1.500          -25.000000              -25.000
# 1             -0.099          134.770996                0.350
# 2              2.524          -25.000000              -25.000
# 3             -2.387          -25.000000              -25.000
# 4              2.681           73.082001                3.369
# ...              ...                 ...                  ...
# 1399995       -1.566           66.065002               -2.351
# 1399996       -0.289           24.084999                2.921
# 1399997       -1.921           41.452999               -0.720
# 1399998        2.012           96.839996               -0.338
# 1399999        2.084           55.109001                0.830
#
#          PRI_jet_leading_phi  PRI_jet_subleading_pt  ...    DER_pt_h  \
# 0                    -25.000                -25.000  ...   30.256184
# 1                      2.894                 49.673  ...  124.359779
# 2                    -25.000                -25.000  ...   10.601603
# 3                    -25.000                -25.000  ...   10.455322
# 4                     -1.286                 31.274  ...   92.074677
# ...                      ...                    ...  ...         ...
# 1399995                1.919                -25.000  ...  106.051392
# 1399996                3.066                -25.000  ...   36.822395
# 1399997                2.832                -25.000  ...   47.608471
# 1399998               -2.019                -25.000  ...  115.486450
# 1399999               -2.594                -25.000  ...   69.577713
#
#          DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# 0                     -25.000        -25.000000           -25.000000
# 1                       2.009        232.705902            -0.580650
# 2                     -25.000        -25.000000           -25.000000
# 3                     -25.000        -25.000000           -25.000000
# 4                       3.370        254.889191            -0.003369
# ...                       ...               ...                  ...
# 1399995               -25.000        -25.000000           -25.000000
# 1399996               -25.000        -25.000000           -25.000000
# 1399997               -25.000        -25.000000           -25.000000
# 1399998               -25.000        -25.000000           -25.000000
# 1399999               -25.000        -25.000000           -25.000000
#
#          DER_deltar_had_lep  DER_pt_tot  DER_sum_pt DER_pt_ratio_lep_had  \
# 0                  3.020465   30.256184   84.224998             0.801489
# 1                  1.328600    9.316307  270.459991             0.433361
# 2                  2.991648   10.601603   62.541000             0.491984
# 3                  3.171129   10.455322   76.309998             1.733558
# 4                  2.120175    6.207835  175.192993             1.285286
# ...                     ...         ...         ...                  ...
# 1399995            1.872566   47.462490  126.029007             0.933886
# 1399996            3.123230   18.094448   83.028000             0.675279
# 1399997            2.303879    7.489350  104.884003             0.885807
# 1399998            1.728608   31.709156  219.203003             0.659474
# 1399999            1.956841   15.142760  124.293999             0.956977
#
#          DER_met_phi_centrality  DER_lep_eta_centrality
# 0                      1.365776              -25.000000
# 1                      1.413247                0.726747
# 2                      1.315526              -25.000000
# 3                     -1.409702              -25.000000
# 4                      1.037429                0.366135
# ...                         ...                     ...
# 1399995                1.249402              -25.000000
# 1399996               -1.413561              -25.000000
# 1399997                1.020647              -25.000000
# 1399998                1.358409              -25.000000
# 1399999                0.719659              -25.000000
#
# [1400000 rows x 31 columns]

# %% [markdown]
# ***
# ## Visualize the Data Set
# ***

# %%
from tabulate import tabulate

target = data_set["labels"]
weights = data_set["weights"]
detailed_label = data_set["detailed_labels"]
keys = np.unique(detailed_label)


weight_keys = {}
average_weights = {}
for key in keys:
    weight_keys[key] = weights[detailed_label == key]

table_data = []
for key in keys:
    table_data.append(
        [
            key,
            np.sum(weight_keys[key]),
            len(weight_keys[key]),
            np.mean(weight_keys[key]),
        ]
    )

table_data.append(
    [
        "Total Signal",
        np.sum(weights[target == 1]),
        len(weights[target == 1]),
        np.mean(weights[target == 1]),
    ]
)
table_data.append(
    [
        "Total Background",
        np.sum(weights[target == 0]),
        len(weights[target == 0]),
        np.mean(weights[target == 0]),
    ]
)


print("[*] --- Detailed Label Summary")
print(
    tabulate(
        table_data,
        headers=[
            "Detailed Label",
            "Total Weight",
            "Number of events",
            "Average Weight",
        ],
        tablefmt="grid",
    )
)
# Out:
# [*] --- Detailed Label Summary
# +------------------+----------------+--------------------+------------------+
# | Detailed Label   |   Total Weight |   Number of events |   Average Weight |
# +==================+================+====================+==================+
# | diboson          |        382.109 |               3406 |       0.112187   |
# +------------------+----------------+--------------------+------------------+
# | htautau          |        675.897 |             462981 |       0.00145988 |
# +------------------+----------------+--------------------+------------------+
# | ttbar            |       4404.72  |              39293 |       0.112099   |
# +------------------+----------------+--------------------+------------------+
# | ztautau          |     100256     |             894320 |       0.112103   |
# +------------------+----------------+--------------------+------------------+
# | Total Signal     |        675.897 |             462981 |       0.00145988 |
# +------------------+----------------+--------------------+------------------+
# | Total Background |     105043     |             937019 |       0.112103   |
# +------------------+----------------+--------------------+------------------+

# %%
print("\n[*] --- Examples of all features\n")
display(data_set.head())
# Out:
# [*] --- Examples of all features
#    PRI_lep_pt  PRI_lep_eta  PRI_lep_phi  PRI_had_pt  PRI_had_eta  PRI_had_phi  \
# 0   37.472000        0.676       -1.520   46.752998        0.623        1.500
# 1   26.006001       -0.087       -1.412   60.009998       -0.290       -0.099
# 2   20.622999       -0.922       -0.436   41.917999       -1.356        2.524
# 3   48.394001        0.202        0.816   27.916000       -0.552       -2.387
# 4   39.840000       -0.005        1.487   30.997000        1.747        2.681
#
#    PRI_jet_leading_pt  PRI_jet_leading_eta  PRI_jet_leading_phi  \
# 0          -25.000000              -25.000              -25.000
# 1          134.770996                0.350                2.894
# 2          -25.000000              -25.000              -25.000
# 3          -25.000000              -25.000              -25.000
# 4           73.082001                3.369               -1.286
#
#    PRI_jet_subleading_pt  ...    DER_pt_h  DER_deltaeta_jet_jet  \
# 0                -25.000  ...   30.256184               -25.000
# 1                 49.673  ...  124.359779                 2.009
# 2                -25.000  ...   10.601603               -25.000
# 3                -25.000  ...   10.455322               -25.000
# 4                 31.274  ...   92.074677                 3.370
#
#    DER_mass_jet_jet  DER_prodeta_jet_jet  DER_deltar_had_lep  DER_pt_tot  \
# 0        -25.000000           -25.000000            3.020465   30.256184
# 1        232.705902            -0.580650            1.328600    9.316307
# 2        -25.000000           -25.000000            2.991648   10.601603
# 3        -25.000000           -25.000000            3.171129   10.455322
# 4        254.889191            -0.003369            2.120175    6.207835
#
#    DER_sum_pt DER_pt_ratio_lep_had  DER_met_phi_centrality  \
# 0   84.224998             0.801489                1.365776
# 1  270.459991             0.433361                1.413247
# 2   62.541000             0.491984                1.315526
# 3   76.309998             1.733558               -1.409702
# 4  175.192993             1.285286                1.037429
#
#    DER_lep_eta_centrality
# 0              -25.000000
# 1                0.726747
# 2              -25.000000
# 3              -25.000000
# 4                0.366135
#
# [5 rows x 31 columns]

# %%
print("\n[*] --- Description of all features\n")
display(data_set.describe())
# Out:
# [*] --- Description of all features
#          PRI_lep_pt   PRI_lep_eta   PRI_lep_phi    PRI_had_pt   PRI_had_eta  \
# count  1.400000e+06  1.400000e+06  1.400000e+06  1.400000e+06  1.400000e+06
# mean   3.396482e+01 -1.664071e-03  3.532688e-04  4.310186e+01 -1.059442e-03
# std    1.806436e+01  1.223419e+00  1.813047e+00  2.134356e+01  1.246117e+00
# min    2.000000e+01 -2.500000e+00 -3.142000e+00  2.287700e+01 -2.690000e+00
# 25%    2.395100e+01 -9.520000e-01 -1.568000e+00  3.077000e+01 -9.770000e-01
# 50%    2.901600e+01 -1.000000e-03  1.000000e-03  3.816800e+01 -1.000000e-03
# 75%    3.716600e+01  9.500000e-01  1.572000e+00  4.813200e+01  9.730000e-01
# max    1.101770e+03  2.500000e+00  3.142000e+00  8.452980e+02  2.680000e+00
#
#         PRI_had_phi  PRI_jet_leading_pt  PRI_jet_leading_eta  \
# count  1.400000e+06        1.400000e+06         1.400000e+06
# mean  -7.431224e-04        2.039557e+01        -1.315356e+01
# std    1.813856e+00        6.307355e+01         1.255423e+01
# min   -3.142000e+00       -2.500000e+01        -2.500000e+01
# 25%   -1.572000e+00       -2.500000e+01        -2.500000e+01
# 50%    3.000000e-03       -2.500000e+01        -2.500000e+01
# 75%    1.570000e+00        4.706200e+01        -1.560000e-01
# max    3.142000e+00        1.203860e+03         4.991000e+00
#
#        PRI_jet_leading_phi  PRI_jet_subleading_pt  ...      DER_pt_h  \
# count         1.400000e+06           1.400000e+06  ...  1.400000e+06
# mean         -1.315217e+01          -8.396195e+00  ...  4.182135e+01
# std           1.254495e+01           3.432262e+01  ...  5.431841e+01
# min          -2.500000e+01          -2.500000e+01  ...  1.173875e-02
# 25%          -2.500000e+01          -2.500000e+01  ...  1.094507e+01
# 50%          -2.500000e+01          -2.500000e+01  ...  2.156595e+01
# 75%          -1.780000e-01          -2.500000e+01  ...  4.885020e+01
# max           3.142000e+00           1.001000e+03  ...  1.175087e+03
#
#        DER_deltaeta_jet_jet  DER_mass_jet_jet  DER_prodeta_jet_jet  \
# count          1.400000e+06      1.400000e+06         1.400000e+06
# mean          -1.887505e+01      5.100177e+01        -1.941999e+01
# std            1.143358e+01      2.382271e+02         1.057919e+01
# min           -2.500000e+01     -2.500000e+01        -2.500000e+01
# 25%           -2.500000e+01     -2.500000e+01        -2.500000e+01
# 50%           -2.500000e+01     -2.500000e+01        -2.500000e+01
# 75%           -2.500000e+01     -2.500000e+01        -2.500000e+01
# max            9.666000e+00      6.555388e+03         2.229731e+01
#
#        DER_deltar_had_lep    DER_pt_tot    DER_sum_pt  DER_pt_ratio_lep_had  \
# count        1.400000e+06  1.400000e+06  1.400000e+06          1.400000e+06
# mean         2.738726e+00  1.806350e+01  1.273698e+02          8.796806e-01
# std          6.103445e-01  1.601432e+01  1.094018e+02          5.094582e-01
# min          5.641427e-01  1.173875e-02  4.304400e+01          3.400616e-02
# 25%          2.509546e+00  8.491425e+00  6.449300e+01          5.891082e-01
# 50%          2.957897e+00  1.439308e+01  8.531300e+01          7.759828e-01
# 75%          3.127119e+00  2.271586e+01  1.433570e+02          1.024202e+00
# max          5.804204e+00  7.199706e+02  2.497039e+03          2.160489e+01
#
#        DER_met_phi_centrality  DER_lep_eta_centrality
# count            1.400000e+06            1.400000e+06
# mean             2.691063e-01           -1.930729e+01
# std              1.217131e+00            1.060158e+01
# min             -1.414214e+00           -2.500000e+01
# 25%             -1.332358e+00           -2.500000e+01
# 50%              9.866624e-01           -2.500000e+01
# 75%              1.385667e+00           -2.500000e+01
# max              1.414214e+00            1.000000e+00
#
# [8 rows x 30 columns]

# %%
from utils import histogram_dataset

# this function is defined in utils.py in the sample_code_submission directory. feel free to modify it as needed

histogram_dataset(
    data_set,
    target,
    weights,
    columns=["PRI_lep_phi", "PRI_met", "DER_mass_vis", "DER_deltaeta_jet_jet"],
)
# Out:
# [*] --- PRI_lep_phi histogram
# [*] --- PRI_met histogram
# [*] --- DER_mass_vis histogram
# [*] --- DER_deltaeta_jet_jet histogram

# %%
import seaborn as sns

sns.set_theme(rc={"figure.figsize": (10, 10)}, style="whitegrid")

caption = ["Signal feature", "Background feature"]

for i in range(2):

    dfplot = pd.DataFrame(
        data_set,
        columns=[
            "PRI_lep_phi",
            "PRI_met",
            "DER_pt_ratio_lep_had",
            "DER_deltaeta_jet_jet",
        ],
    )

    print(caption[i], " correlation matrix")
    corrMatrix = dfplot[target == i].corr()
    sns.heatmap(corrMatrix, annot=True)
    plt.title("Correlation matrix of features")
    plt.show()

del dfplot
# Out:
# Signal feature  correlation matrix
# Background feature  correlation matrix

# %%
from HiggsML.visualization import stacked_histogram

stacked_histogram(data_set, target, weights, detailed_label, "PRI_jet_subleading_pt")
# Out:
# keys ['diboson' 'htautau' 'ttbar' 'ztautau']
# keys 2 dict_keys(['diboson', 'htautau', 'ttbar', 'ztautau'])
# htautau (30,)

# %%
from HiggsML.visualization import pair_plots

# Show data summary
pair_plots(
    data_set,
    target,
    sample_size=100,
    columns=[
        "PRI_lep_phi",
        "PRI_met",
        "DER_lep_eta_centrality",
        "DER_deltaeta_jet_jet",
    ],
)

# %% [markdown]
# ### Test Settings
# The Test setting sets the test conditions in ingestion.
# This includes what systematics you want and how many psuedo experiments you want.

# %%
TEST_SETTINGS = {
    "systematics": {  # Systematics to use
        "tes": False,  # tau energy scale
        "jes": False,  # jet energy scale
        "soft_met": False,  # soft term in MET
        "ttbar_scale": False,  # W boson scale factor
        "diboson_scale": False,  # Diboson scale factor
        "bkg_scale": False,  # Background scale factor
    },
    "num_pseudo_experiments": 25,  # Number of pseudo-experiments to run per set
    "num_of_sets": 25,  # Number of sets of pseudo-experiments to run
}

RANDOM_SEED = 42

# %%
test_settings = TEST_SETTINGS.copy()

random_state = np.random.RandomState(RANDOM_SEED)
test_settings["ground_truth_mus"] = (
    random_state.uniform(0.1, 3, test_settings["num_of_sets"])
).tolist()

random_settings_file = os.path.join(output_dir, "test_settings.json")
with open(random_settings_file, "w") as f:
    json.dump(test_settings, f)

# %% [markdown]
# ### Ingestion

# %%
from HiggsML.ingestion import Ingestion

ingestion = Ingestion(data)

# %%
# initialize submission
ingestion.init_submission(Model, "BDT")
# Out:
# 2025-06-05 21:29:09,686 - HiggsML.ingestion    - INFO     - Initializing Submmited Model
# 2025-06-05 21:29:09,957 - HiggsML.datasets     - INFO     - Selected train size: 500000
# 2025-06-05 21:29:10,854 - HiggsML.datasets     - INFO     - Data loaded successfully
# 2025-06-05 21:29:11,055 - HiggsML.datasets     - INFO     - Selected train size: 850000
# Training Data:  (500000, 28)
# Training Labels:  (500000,)
# Training Weights:  (500000,)
# sum_signal_weights:  676.8253662468933
# sum_bkg_weights:  105042.17463375312
# 2025-06-05 21:29:12,047 - HiggsML.datasets     - INFO     - Data loaded successfully
# 2025-06-05 21:29:12,230 - HiggsML.datasets     - INFO     - Selected train size: 50000
# Valid Data:  (850000, 28)
# Valid Labels:  (850000,)
# Valid Weights:  (850000,)
# sum_signal_weights:  675.4324900975153
# sum_bkg_weights:  105043.56750990245
# 2025-06-05 21:29:12,801 - HiggsML.datasets     - INFO     - Data loaded successfully
# Holdout Data:  (50000, 28)
# Holdout Labels:  (50000,)
# Holdout Weights:  (50000,)
# sum_signal_weights:  674.5085603972545
# sum_bkg_weights:  105044.49143960272
#
#
# Training Data:  (500000, 28)
# Force retraining the model, loading pretrained model skipped.
#  Model is BDT

# %%
# fit submission
ingestion.fit_submission()
# Out:
# 2025-06-05 21:29:12,851 - HiggsML.ingestion    - INFO     - Calling fit method of submitted model
#  Model saved : model_1.pkl
#  Scaler saved : scaler_1.pkl
# score shape before threshold (45783,)
# score shape after threshold (45783,)
# saved_info {'beta': np.float64(14234.183772881293), 'gamma': np.float64(496.5800219493076), 'tes_fit': (<function tes_fitter.<locals>.fit_function at 0x0000027F80E9A7A0>, <function tes_fitter.<locals>.eval_alpha at 0x0000027F80E9A700>), 'jes_fit': <function jes_fitter.<locals>.fit_function at 0x0000027F81ACB560>}
# Train Results:
# 	 mu_hat  :  0.22239278391171577
# 	 del_mu_stat  :  0.24441248662793735
# 	 del_mu_sys  :  0.0
# 	 del_mu_tot  :  0.24441248662793735
# Holdout Results:
# 	 mu_hat  :  0.9999999999999982
# 	 del_mu_stat  :  0.24441248662793735
# 	 del_mu_sys  :  0.0
# 	 del_mu_tot  :  0.24441248662793735
# Valid Results:
# 	 mu_hat  :  1.44665869827152
# 	 del_mu_stat  :  0.24441248662793735
# 	 del_mu_sys  :  0.0
# 	 del_mu_tot  :  0.24441248662793735
# Significance (Asimov):
# 	Maximum Asimov significance: 6.4061
# [*] --- score histogram
# keys ['diboson' 'htautau' 'ttbar' 'ztautau']
# keys 2 dict_keys(['diboson', 'htautau', 'ttbar', 'ztautau'])
# htautau (30,)

# %%
# load test set
data.load_test_set()
# Out:
# 2025-06-05 21:30:09,327 - HiggsML.datasets     - INFO     - Data loaded successfully
# 2025-06-05 21:30:09,943 - HiggsML.datasets     - INFO     - Test data loaded successfully

# %%
# predict submission
ingestion.predict_submission(test_settings)
# Out:
# 2025-06-05 21:30:09,966 - HiggsML.ingestion    - INFO     - Calling predict method of submitted model with seed: 31415
# score shape before threshold (45783,)
# score shape after threshold (45783,)
# saved_info {'beta': np.float64(14234.183772881293), 'gamma': np.float64(496.5800219493076), 'tes_fit': (<function tes_fitter.<locals>.fit_function at 0x0000027F84C327A0>, <function tes_fitter.<locals>.eval_alpha at 0x0000027F84C305E0>), 'jes_fit': <function jes_fitter.<locals>.fit_function at 0x0000027F81E439C0>}
# Test Results:  {'mu_hat': np.float64(2.170478431427379), 'del_mu_stat': np.float64(0.24441248662793735), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.24441248662793735)}
# score shape before threshold (45783,)
# score shape after threshold (45783,)
# saved_info {'beta': np.float64(14234.183772881293), 'gamma': np.float64(496.5800219493076), 'tes_fit': (<function tes_fitter.<locals>.fit_function at 0x0000027F81AC84A0>, <function tes_fitter.<locals>.eval_alpha at 0x0000027F81AC8D60>), 'jes_fit': <function jes_fitter.<locals>.fit_function at 0x0000027F81E43CE0>}
# Test Results:  {'mu_hat': np.float64(1.0548475652775644), 'del_mu_stat': np.float64(0.24441248662793735), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.24441248662793735)}
# score shape before threshold (45783,)
# score shape after threshold (45783,)
# saved_info {'beta': np.float64(14234.183772881293), 'gamma': np.float64(496.5800219493076), 'tes_fit': (<function tes_fitter.<locals>.fit_function at 0x0000027F80266340>, <function tes_fitter.<locals>.eval_alpha at 0x0000027F80266A20>), 'jes_fit': <function jes_fitter.<locals>.fit_function at 0x0000027F81E4C540>}
# Test Results:  {'mu_hat': np.float64(2.957864114937447), 'del_mu_stat': np.float64(0.24441248662793735), 'del_mu_sys': np.float64(0.0), 'del_mu_tot': np.float64(0.24441248662793735)}
# score shape before threshold (45783,)
# score shape after threshold (45783,)

# %%
ingestion.process_results_dict()

# %%
# save result
ingestion.save_result(output_dir)

# %% [markdown]
# ## Score
# 1. Compute Scores
# 2. Visualize Scores

# %%
from HiggsML.score import Scoring

# %%
# Initialize Score
score = Scoring()

# %%
print(output_dir)
score.load_ingestion_results(prediction_dir=output_dir, score_dir=output_dir)

# %%
# Compute Score
score.compute_scores(test_settings)

# %%
from HiggsML.visualization import visualize_scatter

# Visualize scatter plot of ground truth mu and predicted mu
visualize_scatter(
    ingestion_result_dict=ingestion.results_dict,
    ground_truth_mus=test_settings["ground_truth_mus"],
)

# %%
# !python -m HiggsML.score --prediction $output_dir --output $output_dir
